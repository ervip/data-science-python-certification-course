# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
hurricanes = pd.read_csv(r'D:\CourseWork\data-science-python-certification-course\Assignments\04 Introduction to NumPy, Pandas, and Matplotlib\Case Study III\resources\Hurricanes.csv')
city_temps = pd.read_csv(r'D:\CourseWork\data-science-python-certification-course\Assignments\04 Introduction to NumPy, Pandas, and Matplotlib\Case Study III\resources\CityTemps.csv')

# %%
# Question 1

"""
You are given a dataset, which is present in the LMS, containing the number of 
hurricanes occurring in the United States along the coast of the Atlantic. Load the 
data from the dataset into your program and plot a Bar Graph of the data, taking 
the Year as the x-axis and the number of hurricanes occurring as the Y-axis. 
"""

plt.bar(hurricanes['Year'], hurricanes['Hurricanes'])
plt.xlabel('Years =>')
plt.ylabel('Hurricanes =>')
plt.show()

# %%
# Question 2

"""
The dataset given, records data of city temperatures over the years 2014 and 
2015. Plot the histogram of the temperatures over this period for the cities of 
San Francisco and Moscow.
"""

moscow = city_temps['Moscow']
sf = city_temps['San Francisco']

plt.hist(moscow, len(moscow), color='purple', alpha=0.5)
plt.hist(sf, len(sf), color='blue', alpha=0.5)

plt.xlabel('Temperature')
plt.ylabel('Frequency')

plt.show()

# %%
# Question 3

"""
Create CSV file from the data file available in LMS which goes by the name 
'M4_assign_dataset' and read this file into a pandas data frame
"""

# Answer: FILE ('M4_assign_dataset') NOT AVAILABLE IN LMS

# %%
# Question 4 & 5

"""
Let the x-axis data points and y-axis data points are
X = [1,2,3,4]
y = [20, 21, 20.5, 20.8]
"""

X = [1,2,3,4]
Y = [20, 21, 20.5, 20.8]

# %%
# 5.1 Draw a Simple plot

plt.plot(X, Y)
plt.show()

# %%
# 5.2  Configure the line and markers in a simple plot

plt.plot(X, Y)
plt.grid()
plt.show()

# %%
# 5.3 configure the axes


plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='right')

# %%
# 5.4 Give the title of Graph & labels of the x axis and y axis

plt.plot(X, Y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# 5.5 Give error bar if  y_error = [0.12, 0.13, 0.2, 0.1]

plt.plot(X, Y, [0.12, 0.13, 0.2, 0.1])
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
# 5.6 define width, height as figsize=(4,5) DPI and adjust plot dpi=100

plt.figure(figsize=(4, 5), dpi=100)

# %%
# 5.7 Give a font size of 14

plt.rcParams.update({'font.size': 14})

# %%
# 5.8 Draw a scatter graph of any 50 random values of x and y axis

plt.scatter(np.random.random(50), np.random.random(50))
plt.show()

# %%
"""
5.9 Create a dataframe from following data
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]

Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
"""

tdf = pd.DataFrame({
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
})

plt.scatter(tdf['preTestScore'], tdf['postTestScore'], s=tdf['age'])
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.show()

# %%
"""
5.10

Draw a Scatterplot from the data in question 9 of preTestScore and 
postTestScore with the size = 300 and the color determined by sex

"""

plt.scatter(tdf['preTestScore'], tdf['postTestScore'], s=300, c=tdf['female'])
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.show()
